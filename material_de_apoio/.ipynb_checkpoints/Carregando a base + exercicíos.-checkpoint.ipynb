# %%
import pandas as pd

# %%
compras = pd.read_excel("compras_loja_a.xlsx")

# %%
compras.shape
# Out:
# (46, 7)

# %% [markdown]
# A base possui valores duplicados?

# %%
compras.columns
# Out:
# Index(['Data', 'Região', 'Representante', 'Item', 'Unidade', 'Preço Unidade',
#        'Total'],
#       dtype='object')

# %%
compras.groupby(['Data', 'Região', 'Representante', \
                 'Item'])

# %%
compras = compras.drop_duplicates()

# %%
compras.shape
# Out:
# (43, 7)

# %% [markdown]
# A base possui valores ausentes?

# %%
compras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 45
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Data           43 non-null     object
#  1   Região         43 non-null     object
#  2   Representante  43 non-null     object
#  3   Item           42 non-null     object
#  4   Unidade        42 non-null     float64
#  5   Preço Unidade  41 non-null     object
#  6   Total          40 non-null     float64
# dtypes: float64(2), object(5)
# memory usage: 2.7+ KB

# %%
compras[compras.isnull().any(axis=1)]
# Out:
#         Data  Região Representante     Item  Unidade Preço Unidade   Total
# 33   31/5/19  Centro          Gill  Caderno     80.0          8.99     NaN
# 34   17/6/19  Centro        Kivell      NaN      5.0           125  625.00
# 40   27/9/19   Oeste       Sorvino      Pen     76.0          1.99     NaN
# 42  31/10/19  Centro       Andrews    Lapis     14.0           NaN   18.06
# 45  21/12/19  Centro       Andrews  Caderno      NaN           NaN     NaN

# %%
compras.drop(45)
# Out:
#         Data  Região Representante     Item  Unidade Preço Unidade    Total
# 0     6/1/18   Leste         Jones    Lapis     95.0          1.99   189.05
# 1    23/1/18  Centro        Kivell  Caderno     50.0         19.99   999.50
# 3     9/2/18  Centro       Jardine    Lapis     36.0          4.99   179.64
# 4   26-2-/18  Centro          Gill      Pen     27.0         19.99   539.73
# 5    15/3/18   Oeste       Sorvino    Lapis     56.0          2.99   167.44
# 6     1/4/18   Leste         Jones  Caderno     60.0          4.99   299.40
# 7    18/4/18  Centro       Andrews    Lapis     75.0          1.99   149.25
# 8     5-5-18  Centro       Jardine    Lapis     90.0          4.99   449.10
# 9    22/5/18   Oeste      Thompson    Lapis     32.0          1.99    63.68
# 10    8/6/18   Leste         Jones  Caderno     60.0          8.99   539.40
# 11   25/6/18  Centro        Morgan    Lapis     90.0          4.99   449.10
# ...

# %%
compras.drop(45, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-e8c0f1341c97> in <module>
# ----> 1 compras.drop(45, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
compras[compras.isnull().any(axis=1)]
# Out:
#         Data  Região Representante   Item  Unidade Preço Unidade  Total
# 40   27/9/19   Oeste       Sorvino    Pen     76.0          1.99    NaN
# 42  31/10/19  Centro       Andrews  Lapis     14.0           NaN  18.06

# %%
compras.loc[33, "Total"] = compras.loc[33, "Unidade"] * compras.loc[33, "Preço Unidade"]
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
compras
# Out:
#         Data  Região Representante     Item  Unidade Preço Unidade    Total
# 0     6/1/18   Leste         Jones    Lapis     95.0          1.99   189.05
# 1    23/1/18  Centro        Kivell  Caderno     50.0         19.99   999.50
# 3     9/2/18  Centro       Jardine    Lapis     36.0          4.99   179.64
# 4   26-2-/18  Centro          Gill      Pen     27.0         19.99   539.73
# 5    15/3/18   Oeste       Sorvino    Lapis     56.0          2.99   167.44
# 6     1/4/18   Leste         Jones  Caderno     60.0          4.99   299.40
# 7    18/4/18  Centro       Andrews    Lapis     75.0          1.99   149.25
# 8     5-5-18  Centro       Jardine    Lapis     90.0          4.99   449.10
# 9    22/5/18   Oeste      Thompson    Lapis     32.0          1.99    63.68
# 10    8/6/18   Leste         Jones  Caderno     60.0          8.99   539.40
# 11   25/6/18  Centro        Morgan    Lapis     90.0          4.99   449.10
# ...

# %%
compras.loc[40, "Total"] = compras.loc[40, "Unidade"] * compras.loc[40, "Preço Unidade"]
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
compras
# Out:
#         Data  Região Representante     Item  Unidade Preço Unidade    Total
# 0     6/1/18   Leste         Jones    Lapis     95.0          1.99   189.05
# 1    23/1/18  Centro        Kivell  Caderno     50.0         19.99   999.50
# 3     9/2/18  Centro       Jardine    Lapis     36.0          4.99   179.64
# 4   26-2-/18  Centro          Gill      Pen     27.0         19.99   539.73
# 5    15/3/18   Oeste       Sorvino    Lapis     56.0          2.99   167.44
# 6     1/4/18   Leste         Jones  Caderno     60.0          4.99   299.40
# 7    18/4/18  Centro       Andrews    Lapis     75.0          1.99   149.25
# 8     5-5-18  Centro       Jardine    Lapis     90.0          4.99   449.10
# 9    22/5/18   Oeste      Thompson    Lapis     32.0          1.99    63.68
# 10    8/6/18   Leste         Jones  Caderno     60.0          8.99   539.40
# 11   25/6/18  Centro        Morgan    Lapis     90.0          4.99   449.10
# ...

# %%
compras.loc[42, "Preço Unidade"] = compras.loc[42, "Total"] / compras.loc[42, "Unidade"]
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
compras
# Out:
#         Data  Região Representante     Item  Unidade Preço Unidade    Total
# 0     6/1/18   Leste         Jones    Lapis     95.0          1.99   189.05
# 1    23/1/18  Centro        Kivell  Caderno     50.0         19.99   999.50
# 3     9/2/18  Centro       Jardine    Lapis     36.0          4.99   179.64
# 4   26-2-/18  Centro          Gill      Pen     27.0         19.99   539.73
# 5    15/3/18   Oeste       Sorvino    Lapis     56.0          2.99   167.44
# 6     1/4/18   Leste         Jones  Caderno     60.0          4.99   299.40
# 7    18/4/18  Centro       Andrews    Lapis     75.0          1.99   149.25
# 8     5-5-18  Centro       Jardine    Lapis     90.0          4.99   449.10
# 9    22/5/18   Oeste      Thompson    Lapis     32.0          1.99    63.68
# 10    8/6/18   Leste         Jones  Caderno     60.0          8.99   539.40
# 11   25/6/18  Centro        Morgan    Lapis     90.0          4.99   449.10
# ...

# %% [markdown]
# A base tem formatação diferente?

# %%
compras.Data = compras.Data.str.replace("-","/")
# Out:
# C:\Users\lucas\anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
compras.Data = compras.Data.str.replace("//","/")

# %%
compras
# Out:
#         Data  Região Representante     Item  Unidade Preço Unidade    Total
# 0     6/1/18   Leste         Jones    Lapis     95.0          1.99   189.05
# 1    23/1/18  Centro        Kivell  Caderno     50.0         19.99   999.50
# 3     9/2/18  Centro       Jardine    Lapis     36.0          4.99   179.64
# 4    26/2/18  Centro          Gill      Pen     27.0         19.99   539.73
# 5    15/3/18   Oeste       Sorvino    Lapis     56.0          2.99   167.44
# 6     1/4/18   Leste         Jones  Caderno     60.0          4.99   299.40
# 7    18/4/18  Centro       Andrews    Lapis     75.0          1.99   149.25
# 8     5/5/18  Centro       Jardine    Lapis     90.0          4.99   449.10
# 9    22/5/18   Oeste      Thompson    Lapis     32.0          1.99    63.68
# 10    8/6/18   Leste         Jones  Caderno     60.0          8.99   539.40
# 11   25/6/18  Centro        Morgan    Lapis     90.0          4.99   449.10
# ...

# %%
preco_ajustado = []
for preco in compras["Preço Unidade"]:
    preco_ajustado.append(float(str(preco).replace(";",".")))

# %%
compras["Preço Unidade"] = preco_ajustado
# Out:
# <ipython-input-40-b02df950a321>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   compras["Preço Unidade"] = preco_ajustado

# %%
compras
# Out:
#         Data  Região Representante     Item  Unidade  Preço Unidade    Total
# 0     6/1/18   Leste         Jones    Lapis     95.0           1.99   189.05
# 1    23/1/18  Centro        Kivell  Caderno     50.0          19.99   999.50
# 3     9/2/18  Centro       Jardine    Lapis     36.0           4.99   179.64
# 4    26/2/18  Centro          Gill      Pen     27.0          19.99   539.73
# 5    15/3/18   Oeste       Sorvino    Lapis     56.0           2.99   167.44
# 6     1/4/18   Leste         Jones  Caderno     60.0           4.99   299.40
# 7    18/4/18  Centro       Andrews    Lapis     75.0           1.99   149.25
# 8     5/5/18  Centro       Jardine    Lapis     90.0           4.99   449.10
# 9    22/5/18   Oeste      Thompson    Lapis     32.0           1.99    63.68
# 10    8/6/18   Leste         Jones  Caderno     60.0           8.99   539.40
# 11   25/6/18  Centro        Morgan    Lapis     90.0           4.99   449.10
# ...

# %%
compras.to_excel("compras_ajustado.xlsx")

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///compras.db')

# %%
compras.to_sql('compras', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-52c78a566c12> in <module>
# ----> 1 compras.to_sql('compras', con=engine)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404             dtype=dtype,
#    1405         )
# ...

# %%
[engine.execute("select * from compras").fetchall()]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-3cd84cc53265> in <module>
# ----> 1 compras[engine.execute("select * from compras").fetchall()]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ...

# %%
pd.read_sql_query("Select * From compras", engine)
# Out:
#     index      Data  Região Representante     Item  Unidade  Preço Unidade  \
# 0       0    6/1/18   Leste         Jones    Lapis     95.0           1.99
# 1       1   23/1/18  Centro        Kivell  Caderno     50.0          19.99
# 2       3    9/2/18  Centro       Jardine    Lapis     36.0           4.99
# 3       4   26/2/18  Centro          Gill      Pen     27.0          19.99
# 4       5   15/3/18   Oeste       Sorvino    Lapis     56.0           2.99
# 5       6    1/4/18   Leste         Jones  Caderno     60.0           4.99
# 6       7   18/4/18  Centro       Andrews    Lapis     75.0           1.99
# 7       8    5/5/18  Centro       Jardine    Lapis     90.0           4.99
# 8       9   22/5/18   Oeste      Thompson    Lapis     32.0           1.99
# 9      10    8/6/18   Leste         Jones  Caderno     60.0           8.99
# 10     11   25/6/18  Centro        Morgan    Lapis     90.0           4.99
# ...

# %%
pd.read_sql_query("Select Data, Região from compras", engine)
# Out:
#         Data  Região
# 0     6/1/18   Leste
# 1    23/1/18  Centro
# 2     9/2/18  Centro
# 3    26/2/18  Centro
# 4    15/3/18   Oeste
# 5     1/4/18   Leste
# 6    18/4/18  Centro
# 7     5/5/18  Centro
# 8    22/5/18   Oeste
# 9     8/6/18   Leste
# 10   25/6/18  Centro
# 11   12/7/18   Leste
# 12   29/7/18   Leste
# 13   15/8/18   Leste
# 14    1/9/18  Centro
# 15   18/9/18   Leste
# 16   5/10/18  Centro
# 17  22/10/18   Leste
# 18   8/11/18   Leste
# 19  25/11/18  Centro
# 20  12/12/18  Centro
# 21  29/12/18   Leste
# 22   15/1/19  Centro
# 23    1/2/19  Centro
# 24   18/2/19   Leste
# 25    7/3/19   Oeste
# 26   24/3/19  Centro
# 27   10/4/19  Centro
# 28   27/4/19   Leste
# 29   14/5/19  Centro
# 30   31/5/19  Centro
# 31    4/7/19   Leste
# 32   21/7/19  Centro
# 33    7/8/19  Centro
# 34   24/8/19   Oeste
# 35   10/9/19  Centro
# 36   27/9/19   Oeste
# 37  14/10/19   Oeste
# 38  31/10/19  Centro
# 39  17/11/19  Centro
# 40   4/12/19  Centro
